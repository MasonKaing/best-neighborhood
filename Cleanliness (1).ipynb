# %% [markdown]
# ## All Neighborhoods' Offense Counts

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
clean = pd.read_csv("CleanlinessDataset.csv")
neighborhood_counts = clean['NEIGHBORHOOD'].value_counts()
print(neighborhood_counts)
# Out:
# NEIGHBORHOOD
# Brookline                    27745
# Carrick                      26202
# Squirrel Hill South          22679
# South Side Slopes            22312
# South Side Flats             21128
# Bloomfield                   18268
# Mount Washington             17502
# Beechview                    15792
# Central Business District    14365
# Greenfield                   14066
# Shadyside                    13736
# Hazelwood                    12288
# Central Lawrenceville        12233
# East Liberty                 11681
# Brighton Heights             11358
# Sheraden                     10992
# Squirrel Hill North          10956
# Marshall-Shadeland           10584
# Lincoln-Lemington-Belmar     10414
# Garfield                     10234
# Highland Park                 9811
# Knoxville                     9595
# Stanton Heights               9494
# Perry North                   9460
# Overbrook                     9372
# Perry South                   9094
# ...

# %% [markdown]
# ## All Neighborhoods' Populations

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
clean = pd.read_csv("Population.csv")
neighborhood_counts = clean[['Neighborhood','2020_Total_Population']]
print(neighborhood_counts)
# Out:
#                                 Neighborhood  2020_Total_Population
# 0                           Allegheny Center                   1419
# 1                             Allegheny West                    540
# 2                                  Allentown                   2305
# 3   Arlington - Arlington Heights (Combined)                   2040
# 4                                 Banksville                   4127
# 5                          Bedford Dwellings                   1386
# 6                                  Beechview                   7596
# 7                                Beltzhoover                   1604
# 8                                 Bloomfield                   8665
# 9                                      Bluff                   5882
# 10                                   Bon Air                    759
# 11                          Brighton Heights                   7105
# 12                                 Brookline                  13063
# ...

# %% [markdown]
# ## Actual examples of cleaning offenses

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
clean = pd.read_csv("CleanlinessDataset.csv")
print(clean['REQUEST_TYPE'].unique())
# Out:
# ['Street Obstruction/Closure' 'Graffiti' 'Litter' 'Water Main Break'
#  'Guide Rail' 'Sidewalk/Curb/HC Ramp Maintenance' 'Manhole Cover '
#  'Neighborhood Issues' "Mayor's Office" 'Blocked or Closed Sidewalks'
#  'Abandoned Vehicle (parked on street)' 'Parks Trails' 'Leak'
#  'Illegal Dumping' 'Sidewalk Obstruction' 'Other' 'Bridge Maintenance'
#  'Utility Cut - Other' 'Tree Fallen Across Sidewalk'
#  'Permits, Licenses and Inspections' 'Traffic Enforcement'
#  'Dead Tree (3TB)' 'Park Shelter' 'Traffic Shop '
#  'Traffic or Pedestrian Signal, Repair' 'Handicap Parking Signs'
#  'Request New Sign' 'Tree Fallen Across Road'
#  'Unpermitted Fire System Work' 'Paving Concern/Problem'
#  'Dead tree (Public property)' 'Building Maintenance' 'Drainage/Leak'
#  'Replace/Repair a Sign' 'Water/Drinking Fountains' 'Landslide'
#  'Traffic or Pedestrian Signal, Request ' 'Litter, Public Property'
#  'Sinkhole' 'Curb Paint' 'Weeds/Debris' 'Drug Enforcement'
# ...
