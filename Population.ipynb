# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
clean = pd.read_csv("Population.csv")
neighborhood_counts = clean[['Neighborhood','2010_Total_Population,2020_Total']]
print(neighborhood_counts)
# Out:
#                                 Neighborhood  2010_Total_Population
# 0                           Allegheny Center                    933
# 1                             Allegheny West                    462
# 2                                  Allentown                   2500
# 3   Arlington - Arlington Heights (Combined)                   2113
# 4                                 Banksville                   4144
# 5                          Bedford Dwellings                   1202
# 6                                  Beechview                   7974
# 7                                Beltzhoover                   1925
# 8                                 Bloomfield                   8442
# 9                                      Bluff                   6600
# 10                                   Bon Air                    808
# 11                          Brighton Heights                   7247
# 12                                 Brookline                  13214
# ...
